# %%
from gensim.models import Word2Vec
import os
import pandas as pd
# Out:
# Using gpu device 0: GeForce GTX 970 (CNMeM is enabled with initial size: 80.0% of memory, cuDNN 5103)
# C:\Anaconda2\lib\site-packages\theano\sandbox\cuda\__init__.py:599: UserWarning: Your cuDNN version is more recent than the one Theano officially supports. If you see any problems, try updating Theano or downgrading cuDNN to version 5.
#   warnings.warn(warn)

# %%
model = Word2Vec.load(os.path.join("models", "GoT"))

# %%
len(model.vocab)
# Out:
# 12232

# %%
rl = model['rhaegar'] + model['lyanna']

# %%
rl
# Out:
# array([-0.38572991,  0.11924084,  0.21511963,  0.24238285,  0.0513475 ,
#        -0.27698213, -0.16949224, -0.11382039,  0.0976632 , -0.11495895,
#        -0.05327811, -0.21775565,  0.09384545,  0.04742137, -0.12481011,
#         0.09260985, -0.02500098,  0.03532022, -0.04965299, -0.07147732,
#         0.07282798, -0.26369795,  0.21061979,  0.01061284, -0.09351711,
#         0.12959339,  0.08102841, -0.17799762, -0.03215126, -0.11978512,
#        -0.26146528,  0.04051451,  0.23134883, -0.29449016,  0.07803507,
#        -0.20064647, -0.12246197,  0.26941845, -0.29311171,  0.03981404,
#        -0.07485669, -0.39643031, -0.02994747,  0.3730616 , -0.15871716,
#         0.00368083,  0.23532498, -0.19786176,  0.07011267,  0.01257428,
#         0.06111684,  0.07362348,  0.36085173, -0.25905916, -0.04498909,
#        -0.3636139 ,  0.17215675,  0.18506086,  0.0742556 ,  0.24865879,
#        -0.06608982, -0.01255994, -0.15412457,  0.26746705,  0.07635751,
# ...

# %%
model['jon']
# Out:
# array([-0.0679348 ,  0.12619473,  0.05942123,  0.06265529,  0.36334398,
#        -0.14419888,  0.18961705, -0.22945592,  0.12605441,  0.09933247,
#         0.26384607, -0.00596822,  0.02888221,  0.18270439, -0.26440746,
#         0.14039923,  0.15191202,  0.36665854,  0.14846283, -0.23959784,
#         0.12094251, -0.16267028, -0.00977125,  0.09968875, -0.38022929,
#        -0.1084977 ,  0.03025811, -0.06925899, -0.39918596, -0.08956069,
#        -0.34020406,  0.07161682, -0.38729364,  0.30707341, -0.11713433,
#        -0.10239025, -0.17349425, -0.29214212, -0.14796096,  0.18875597,
#        -0.07241707, -0.22112344,  0.41837612, -0.11676007,  0.25699773,
#        -0.08278809, -0.02579823, -0.15270963,  0.09582852, -0.06122557,
#         0.15307008, -0.35524952,  0.24318603, -0.17065564,  0.03035067,
#         0.20963609,  0.1824875 , -0.10133382,  0.14651553, -0.11094194,
#        -0.15506609, -0.22318046,  0.07881862,  0.05368612,  0.12342326,
# ...

# %%
import numpy as np

# %%
np.dot(model['jon'], rl)
# Out:
# 0.72033298

# %%
wordvectors = {key:model[key] for key in model.vocab.iterkeys()}

# %%
import pandas as pd

# %%
df = pd.DataFrame(wordvectors)

# %%
df = df.T

# %%
df
# Out:
#                     0         1         2         3         4         5   \
# 0             0.005864 -0.064526 -0.028160 -0.047968 -0.005986  0.004180
# 1             0.006613 -0.018674  0.017514  0.088679 -0.022546 -0.042439
# 11           -0.027099  0.000201 -0.016306  0.028000 -0.008929 -0.010412
# a            -0.005063 -0.278850  0.053789  0.145659  0.188200 -0.418610
# aback        -0.059763  0.039303  0.130170  0.006664  0.055100 -0.005132
# abandon      -0.001386  0.131507  0.058878  0.058641 -0.092815  0.043180
# abandoned    -0.094196  0.056413  0.000050  0.221917  0.003161 -0.064642
# abandoning   -0.016840 -0.016789  0.002662 -0.014920 -0.021405  0.025955
# abashed       0.019639  0.060877  0.088883  0.000610  0.057682  0.046334
# abed         -0.023165  0.021317  0.107934  0.045600  0.062956 -0.111027
# abel         -0.005833  0.024053 -0.005548  0.003567 -0.004748  0.008831
# abels         0.002599 -0.009517 -0.002618 -0.004742  0.008903 -0.006517
# ...

# %%
model.most_similar('yunkai')
# Out:
# [('meereen', 0.8105028867721558),
#  ('astapor', 0.7737289667129517),
#  ('volantis', 0.7480388283729553),
#  ('lys', 0.7475703358650208),
#  ('qarth', 0.6611312627792358),
#  ('tolos', 0.6552383899688721),
#  ('oldtown', 0.6521409153938293),
#  ('slaves', 0.6485913395881653),
#  ('tyrosh', 0.6447490453720093),
#  ('westeros', 0.6363445520401001)]

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

# %%
tsne = TSNE(n_components=2, random_state=1337)
pca = PCA(n_components=2)

# %%
tsnevecs = tsne.fit_transform(df)
wordvecs_2d = pca.fit_transform(df)

# %%
pca.explained_variance_ratio_
tsne.perplexity
# Out:
# 30.0

# %%
wordvecs_2d[0]
# Out:
# array([-0.02907596, -0.04632317], dtype=float32)

# %%
ts = pd.DataFrame(tsnevecs, index=df.index)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ts.to_csv('tsnevecs.csv')

# %%
test = ts.loc[['jon', 'sam', 'tyrion', 'yunkai', 'lyanna', 'rhaegar']]

# %%
test['type'] = 'person'
test.loc['yunkai','type'] = 'city'

# %%
test
# Out:
#                 0         1    type
# jon     -4.123032 -4.582134  person
# sam     -4.090174 -4.637813  person
# tyrion  -3.209864 -5.581316  person
# yunkai   4.420293  0.962637    city
# lyanna   1.208852 -5.417866  person
# rhaegar  1.417989 -1.550032  person

# %%
test.plot(kind='scatter', x=0, y=1)
plt.text(jon[0], jon[1], "jon", fontsize = 12)

# %%
model.most_similar('varys')
# Out:
# [('littlefinger', 0.808519184589386),
#  ('qyburn', 0.7595255970954895),
#  ('marillion', 0.6986022591590881),
#  ('gravely', 0.6949257254600525),
#  ('jory', 0.6637319326400757),
#  ('bluntly', 0.6627321839332581),
#  ('brorm', 0.6593022346496582),
#  ('bronn', 0.657358705997467),
#  ('everyone', 0.6551697254180908),
#  ('edmure', 0.6516442894935608)]

# %%
import seaborn as sns

# %%
jon = test.loc['jon']
jon[0]
# Out:
# -4.1230316333649126

# %%
sns.set(style="white", palette="muted", color_codes=True)
sns.swarmplot(x=0, y=1, hue="type", data=test)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.tick_params(labelbottom='off', labelleft='off')
plt.xlabel("First T-SNE")
plt.ylabel("Second T-SNE")
plt.annotate("jon", xy=(jon[0], jon[1]))

plt.show()

# %%
people = test[test['type'] == 'person']
cities = test[test['type'] == 'city']

special = test.loc[['jon', 'tyrion']]
special
# Out:
#                0         1    type
# jon    -4.123032 -4.582134  person
# tyrion -3.209864 -5.581316  person

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import numpy as np

# %%
N = len(people)


trace0 = go.Scatter(
    x = people[0].values,
    y = people[1].values,
    name = 'people',
    mode = 'markers+text',
    marker = dict(
        size = '16'
    ),
    text = people.index,
    textposition='bottom'
)

trace1 = go.Scatter(
    x = test[test['type'] == 'city'][0].values,
    y = test[test['type'] == 'city'][1].values,
    name = 'cities',
    mode = 'markers+text',
    marker = dict(
        size = '16'
    ),
    text = 'yunkai',
    textposition='bottom'
)

layout = dict(title = 'A Song of Ice and  T-SNE',
              yaxis = dict(zeroline = False),
              xaxis = dict(zeroline = False)
             )

# %%
data = [trace0, trace1]
fig = dict(data=data, layout=layout)
py.iplot(fig, filename='test')
# Out:
# ---------------------------------------------------------------------------
# PlotlyError                               Traceback (most recent call last)
# <ipython-input-242-8996d0e8d211> in <module>()
#       1 data = [trace0, trace1]
#       2 fig = dict(data=data, layout=layout)
# ----> 3 py.iplot(fig, filename='test')
#
# C:\Anaconda2\lib\site-packages\plotly\plotly\plotly.pyc in iplot(figure_or_data, **plot_options)
#     149     if 'auto_open' not in plot_options:
#     150         plot_options['auto_open'] = False
# --> 151     url = plot(figure_or_data, **plot_options)
#     152
#     153     if isinstance(figure_or_data, dict):
#
# C:\Anaconda2\lib\site-packages\plotly\plotly\plotly.pyc in plot(figure_or_data, validate, **plot_options)
#     239
#     240     plot_options = _plot_option_logic(plot_options)
# --> 241     res = _send_to_plotly(figure, **plot_options)
#     242     if res['error'] == '':
#     243         if plot_options['auto_open']:
#
# ...
